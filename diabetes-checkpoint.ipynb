# %% [markdown]
# import numpy as np

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('desktop/project/diabetes.csv')
df.head(15)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-932a18c525e3> in <module>
# ----> 1 df=pd.read_csv('desktop/project/diabetes.csv')
#       2 df.head(15)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df.describe().transpose()
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
df[df.applymap(np.isreal).all(1)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x=df.groupby(['Outcome']).count()
x
# Out:
#          Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# Outcome
# 0                500      500            500            500      500  500
# 1                268      268            268            268      268  268
#
#          DiabetesPedigreeFunction  Age
# Outcome
# 0                             500  500
# 1                             268  268

# %%
df.groupby(['Outcome']).count()
# Out:
#          Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# Outcome
# 0                500      500            500            500      500  500
# 1                268      268            268            268      268  268
#
#          DiabetesPedigreeFunction  Age
# Outcome
# 0                             500  500
# 1                             268  268

# %%
sns.boxplot(df['Outcome'],df['Age'])

# %%
plt.scatter(df['Age'],df['Outcome'])

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.drop(df.index[1],inplace=True)
df.reset_index(inplace=True,drop=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              5      116             74              0        0  25.6
# 2              3       78             50             32       88  31.0
# 3             10      115              0              0        0  35.3
# 4              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 759           10      101             76             48      180  32.9
# 760            2      122             70             27        0  36.8
# 761            5      121             72             23      112  26.2
# 762            1      126             60              0        0  30.1
# 763            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['Ages']=np.where(df['Age']>30 ,'aged','younger')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              5      116             74              0        0  25.6
# 2              3       78             50             32       88  31.0
# 3             10      115              0              0        0  35.3
# 4              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 759           10      101             76             48      180  32.9
# 760            2      122             70             27        0  36.8
# 761            5      121             72             23      112  26.2
# 762            1      126             60              0        0  30.1
# 763            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome     Ages
# 0                       0.627   50        1     aged
# ...

# %%
df['BloodPressure']=np.where(df['BloodPressure']==0 ,df['BloodPressure'].mean(),df['BloodPressure'])
df.head()
# Out:
#    Pregnancies  Glucose BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148            72             35        0  33.6
# 1            5      116            74              0        0  25.6
# 2            3       78            50             32       88  31.0
# 3           10      115            69              0        0  35.3
# 4            2      197            70             45      543  30.5
#
#    DiabetesPedigreeFunction  Age  Outcome Ages
# 0                     0.627   50        1   72
# 1                     0.201   30        0   74
# 2                     0.248   26        1   50
# 3                     0.134   29        0   69
# 4                     0.158   53        1   70

# %%
df.BloodPressure.mean
# Out:
# <bound method Series.mean of 0      72
# 1      74
# 2      50
# 3      69
# 4      70
#        ..
# 759    76
# 760    70
# 761    72
# 762    60
# 763    70
# Name: BloodPressure, Length: 764, dtype: object>

# %%
print(df['Age'].index[2])
# Out:
# 2
